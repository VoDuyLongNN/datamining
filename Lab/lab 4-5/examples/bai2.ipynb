# %%
import pandas

df_dlht = pandas.read_excel('Dlht.xlsx')
df_dlht
# Out:
#     Unnamed: 0   ENO  Age       Dept  Gender Skill  WorkingYear  Salary  \
# 0            0  E001   29         HR  Female   SQL          3.0     825
# 1            1  E002   39         IT    Male  Java          7.0    1450
# 2            2  E003   29         IT    Male   SQL          6.0    1236
# 3            3  E004   38         HR  Female    C#          6.0    1324
# 4            4  E005   28         IT    Male     R          2.0     895
# 5            5  E006   36         MA    Male    C#          5.0     943
# 6            6  E007   27  khongbiet    Male   SQL          2.0    1154
# 7            7  E008   28         MA  Female     R          NaN    1356
# 8            8  E009   37         IT    Male  Java          7.0    1456
# 9            9  E010   37         IT     NaN    C#          6.0     892
# 10          10  E011   34         MA    Male   SQL          6.0    1453
# 11          11  E012   29         HR    Male    C#          5.0     852
# ...

# %%
df_dlht['Gender'].map({'Male':1,'Female':0})
# Out:
# 0     0.0
# 1     1.0
# 2     1.0
# 3     0.0
# 4     1.0
# 5     1.0
# 6     1.0
# 7     0.0
# 8     1.0
# 9     NaN
# 10    1.0
# 11    1.0
# 12    0.0
# 13    0.0
# 14    1.0
# 15    0.0
# 16    1.0
# 17    1.0
# 18    0.0
# 19    1.0
# 20    1.0
# 21    1.0
# 22    0.0
# 23    1.0
# 24    1.0
# 25    1.0
# 26    1.0
# 27    0.0
# 28    0.0
# 29    1.0
# 30    1.0
# 31    0.0
# 32    1.0
# 33    1.0
# 34    0.0
# 35    1.0
# 36    1.0
# 37    1.0
# 38    0.0
# 39    1.0
# 40    1.0
# 41    1.0
# 42    1.0
# 43    0.0
# 44    0.0
# 45    1.0
# Name: Gender, dtype: float64

# %%
pandas.get_dummies(data=df_dlht, columns=['Skill'])
# Out:
#     Unnamed: 0   ENO  Age       Dept  Gender  WorkingYear  Salary  \
# 0            0  E001   29         HR  Female          3.0     825
# 1            1  E002   39         IT    Male          7.0    1450
# 2            2  E003   29         IT    Male          6.0    1236
# 3            3  E004   38         HR  Female          6.0    1324
# 4            4  E005   28         IT    Male          2.0     895
# 5            5  E006   36         MA    Male          5.0     943
# 6            6  E007   27  khongbiet    Male          2.0    1154
# 7            7  E008   28         MA  Female          NaN    1356
# 8            8  E009   37         IT    Male          7.0    1456
# 9            9  E010   37         IT     NaN          6.0     892
# 10          10  E011   34         MA    Male          6.0    1453
# 11          11  E012   29         HR    Male          5.0     852
# 12          12  E013   29         HR  Female          5.0    1183
# ...

# %%
df_dlht['Salary_Cut'] = pandas.cut(df_dlht['Salary'], 3, labels=['Low','Medium','High'])
df_dlht['Salary_Cut']
# Out:
# 0        Low
# 1       High
# 2       High
# 3       High
# 4        Low
# 5        Low
# 6     Medium
# 7       High
# 8       High
# 9        Low
# 10      High
# 11       Low
# 12    Medium
# 13       Low
# 14       Low
# 15       Low
# 16      High
# 17      High
# 18    Medium
# 19       Low
# 20    Medium
# 21      High
# 22      High
# 23      High
# 24       Low
# 25      High
# 26       Low
# 27    Medium
# 28       Low
# 29       Low
# 30      High
# 31       Low
# 32      High
# 33      High
# 34      High
# 35       Low
# 36      High
# 37      High
# 38      High
# 39      High
# 40       Low
# 41    Medium
# 42       Low
# 43      High
# 44      High
# 45    Medium
# Name: Salary_Cut, dtype: category
# Categories (3, object): ['Low' < 'Medium' < 'High']

# %%
df_dlht['OverseaProject'].map({'Yes':1,'No':0})
# Out:
# 0     0
# 1     1
# 2     1
# 3     0
# 4     0
# 5     0
# 6     0
# 7     1
# 8     0
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    0
# 15    0
# 16    1
# 17    1
# 18    0
# 19    0
# 20    0
# 21    0
# 22    1
# 23    0
# 24    0
# 25    1
# 26    0
# 27    1
# 28    0
# 29    0
# 30    0
# 31    0
# 32    1
# 33    1
# 34    0
# 35    0
# 36    0
# 37    0
# 38    1
# 39    0
# 40    0
# 41    1
# 42    0
# 43    1
# 44    0
# 45    0
# Name: OverseaProject, dtype: int64

# %%
df_dlht.drop(['OverseaProject','Gender'], axis=1)
# Out:
#     Unnamed: 0   ENO  Age       Dept Skill  WorkingYear  Salary  TrainedYear  \
# 0            0  E001   29         HR   SQL          3.0     825          3.0
# 1            1  E002   39         IT  Java          7.0    1450          7.0
# 2            2  E003   29         IT   SQL          6.0    1236          NaN
# 3            3  E004   38         HR    C#          6.0    1324          5.0
# 4            4  E005   28         IT     R          2.0     895          3.0
# 5            5  E006   36         MA    C#          5.0     943          3.0
# 6            6  E007   27  khongbiet   SQL          2.0    1154          5.0
# 7            7  E008   28         MA     R          NaN    1356          6.0
# 8            8  E009   37         IT  Java          7.0    1456          5.0
# 9            9  E010   37         IT    C#          6.0     892          3.0
# 10          10  E011   34         MA   SQL          6.0    1453          4.0
# ...

# %%
df_dlht['TrainedYear_Cut'] = pandas.cut(df_dlht['TrainedYear'], bins=[2,3,5,7], labels=['College', 'University', 'Master_PhD'])
df_dlht['TrainedYear_Cut']
# Out:
#     Unnamed: 0   ENO  Age       Dept  Gender Skill  WorkingYear  Salary  \
# 0            0  E001   29         HR  Female   SQL          3.0     825
# 1            1  E002   39         IT    Male  Java          7.0    1450
# 2            2  E003   29         IT    Male   SQL          6.0    1236
# 3            3  E004   38         HR  Female    C#          6.0    1324
# 4            4  E005   28         IT    Male     R          2.0     895
# 5            5  E006   36         MA    Male    C#          5.0     943
# 6            6  E007   27  khongbiet    Male   SQL          2.0    1154
# 7            7  E008   28         MA  Female     R          NaN    1356
# 8            8  E009   37         IT    Male  Java          7.0    1456
# 9            9  E010   37         IT     NaN    C#          6.0     892
# 10          10  E011   34         MA    Male   SQL          6.0    1453
# 11          11  E012   29         HR    Male    C#          5.0     852
# ...
