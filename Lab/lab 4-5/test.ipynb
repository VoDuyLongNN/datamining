# %%
import pandas
import seaborn as mpl
import numpy
import matplotlib.pyplot as mlt

df = pandas.read_csv('EmployeeSalary.csv')
# mpl.set()
# mpl.colors('')

bins = numpy.arange(750,3720,500)
# mpl.boxplot(df)
mlt.hist(df['Salary'],bins=bins)
# mpl.scatterplot(data=df,x='Salary', y='WorkingYears')
# df
# df[(df['Salary'] >= 3300) & (df['Salary'] <= 3800)]
# print(df['Salary'])
print(df['Salary'].min())
df['Salary'].max()
# Out:
# 750
# 3710
