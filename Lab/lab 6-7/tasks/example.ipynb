# %%
import pandas
from  apyori import apriori

data = pandas.read_csv('../105.csv')
data
# Out:
#     Access  CT du lieu  CT may tinh  CNXHKH  Chuyen de   CS du lieu  \
# 0      9.0         9.0          7.0     9.0         8.0        10.0
# 1      6.0         8.0          6.0     7.0         8.0         5.0
# 2      7.0         8.0          7.0     5.0         7.0         5.0
# 3      5.0         6.0          5.0     7.0         3.0         5.0
# 4      5.0         8.0          5.0     7.0         6.0         6.0
# ..     ...         ...          ...     ...         ...         ...
# 94     NaN         6.0          6.0     7.0         6.0         8.0
# 95     NaN         5.0          7.0     6.0         8.0         7.0
# 96     NaN         7.0          7.0     8.0         8.0         9.0
# 97     NaN         7.0          5.0     5.0         6.0         9.0
# 98     NaN         NaN          NaN     NaN         NaN         NaN
#
#     Cong nghe NET   CNphan mem  Dai so so hoc  DS tuyen tinh  ...  \
# 0              NaN         9.0            7.0           10.0  ...
# ...

# %%
data.head(10)
# Out:
#    Access  CT du lieu  CT may tinh  CNXHKH  Chuyen de   CS du lieu  \
# 0     9.0         9.0          7.0     9.0         8.0        10.0
# 1     6.0         8.0          6.0     7.0         8.0         5.0
# 2     7.0         8.0          7.0     5.0         7.0         5.0
# 3     5.0         6.0          5.0     7.0         3.0         5.0
# 4     5.0         8.0          5.0     7.0         6.0         6.0
# 5     5.0         7.0          6.0     5.0         7.0         5.0
# 6     9.0         9.0          7.0     9.0         8.0        10.0
# 7     6.0         8.0          6.0     7.0         8.0         5.0
# 8     7.0         8.0          7.0     5.0         7.0         5.0
# 9     5.0         6.0          5.0     7.0         3.0         5.0
#
#    Cong nghe NET   CNphan mem  Dai so so hoc  DS tuyen tinh  ...  \
# 0             NaN         9.0            7.0           10.0  ...
# 1             NaN         8.0            5.0            7.0  ...
# ...

# %%
records = []
for i in range(0,99):
   records.append([str(data.values[i,j]) for j in range(0,10)])
records
# Out:
# [['9.0', '9.0', '7.0', '9.0', '8.0', '10.0', 'nan', '9.0', '7.0', '10.0'],
#  ['6.0', '8.0', '6.0', '7.0', '8.0', '5.0', 'nan', '8.0', '5.0', '7.0'],
#  ['7.0', '8.0', '7.0', '5.0', '7.0', '5.0', 'nan', '7.0', '7.0', '10.0'],
#  ['5.0', '6.0', '5.0', '7.0', '3.0', '5.0', 'nan', '5.0', '5.0', '7.0'],
#  ['5.0', '8.0', '5.0', '7.0', '6.0', '6.0', 'nan', '6.0', '6.0', '5.0'],
#  ['5.0', '7.0', '6.0', '5.0', '7.0', '5.0', 'nan', '6.0', '7.0', '8.0'],
#  ['9.0', '9.0', '7.0', '9.0', '8.0', '10.0', 'nan', '9.0', '7.0', '10.0'],
#  ['6.0', '8.0', '6.0', '7.0', '8.0', '5.0', 'nan', '8.0', '5.0', '7.0'],
#  ['7.0', '8.0', '7.0', '5.0', '7.0', '5.0', 'nan', '7.0', '7.0', '10.0'],
#  ['5.0', '6.0', '5.0', '7.0', '3.0', '5.0', 'nan', '5.0', '5.0', '7.0'],
#  ['5.0', '8.0', '5.0', '7.0', '6.0', '6.0', 'nan', '6.0', '6.0', '5.0'],
#  ['5.0', '7.0', '6.0', '5.0', '7.0', '5.0', 'nan', '6.0', '7.0', '8.0'],
#  ['5.0', '8.0', '7.0', '5.0', '7.0', '6.0', 'nan', '5.0', '7.0', '9.0'],
# ...

# %%
rules = apriori(records, min_support=0.01, min_confidence=0.3, min_lift=3, min_length=2)
rules_result = list(rules)
rules_result
# Out:
# [RelationRecord(items=frozenset({'0.0', '1.0'}), support=0.05, ordered_statistics=[OrderedStatistic(items_base=frozenset({'0.0'}), items_add=frozenset({'1.0'}), confidence=1.0, lift=20.0), OrderedStatistic(items_base=frozenset({'1.0'}), items_add=frozenset({'0.0'}), confidence=1.0, lift=20.0)]),
#  RelationRecord(items=frozenset({'0.0', '4.0'}), support=0.05, ordered_statistics=[OrderedStatistic(items_base=frozenset({'0.0'}), items_add=frozenset({'4.0'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'4.0'}), items_add=frozenset({'0.0'}), confidence=0.5, lift=10.0)]),
#  RelationRecord(items=frozenset({'4.0', '1.0'}), support=0.05, ordered_statistics=[OrderedStatistic(items_base=frozenset({'1.0'}), items_add=frozenset({'4.0'}), confidence=1.0, lift=10.0), OrderedStatistic(items_base=frozenset({'4.0'}), items_add=frozenset({'1.0'}), confidence=0.5, lift=10.0)]),
# ...

# %%
for item in rules_result:
   pair = item[0]
   items = [x for x in pair]
   print('rule: ' + items[0] + '->' + items[1])
   print('suport: '+ str(item[1]))
   print('confidence:'+str(item[2][0][2]))
   print('lift:'+str(item[2][0][3]))
   print('================================================')
# Out:
# rule: 0.0->1.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: 0.0->4.0
# suport: 0.05
# confidence:1.0
# lift:10.0
# ...
# rule: 4.0->1.0
# suport: 0.05
# confidence:1.0
# lift:10.0
# ...
# rule: 0.0->4.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: 0.0->5.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: 0.0->7.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: nan->0.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: 0.0->4.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: 0.0->4.0
# suport: 0.05
# confidence:1.0
# lift:10.0
# ...
# rule: nan->0.0
# suport: 0.05
# confidence:1.0
# lift:10.0
# ...
# rule: 4.0->5.0
# suport: 0.05
# confidence:1.0
# lift:20.0
# ...
# rule: 7.0->4.0
# suport: 0.05
# confidence:1.0
# lift:10.0
# ...
# rule: nan->4.0
# suport: 0.05
# confidence:1.0
# lift:10.0
# ...
# rule: 10.0->9.0
# suport: 0.05
# confidence:1.0
# lift:3.3333333333333335
# ...
# rule: 9.0->4.0
# suport: 0.05
# confidence:1.0
# lift:3.3333333333333335
# ...
# rule: 9.0->4.0
# suport: 0.05
# confidence:1.0
# ...
